# %% [markdown]
# # Подсчёт параметров lognorm

# %%
for v in res:
    print("____________________________________________________________________________________________")    
    print("v = {0}".format(v))
    plt.figure(1, figsize=(14,10))
    
    plt.subplot(221)
    plt.plot(res[v]['b'],res[v]['p1'], 'g-')
    plt.xlabel(' b')
    plt.ylabel('sigma')    
    plt.title('sigma (b)')

    plt.subplot(222)
    plt.plot(res[v]['b'],res[v]['p2'], 'r-')
    plt.xlabel(' b')
    plt.ylabel('log')    
    plt.title('log (b)')

    plt.subplot(223)
    plt.plot(res[v]['b'],res[v]['p3'], 'b-')
    plt.xlabel('b')
    plt.ylabel('exp(mu)')    
    plt.title('exp(mu) (b)')

    plt.show()
# Out:
# ____________________________________________________________________________________________
# v = 0.5
# ____________________________________________________________________________________________
# v = 0.7
# ____________________________________________________________________________________________
# v = 0.9
# ____________________________________________________________________________________________
# v = 1.1
# ____________________________________________________________________________________________
# v = 1.3
# ____________________________________________________________________________________________
# v = 1.5
# ____________________________________________________________________________________________
# v = 1.7
# ____________________________________________________________________________________________
# v = 1.9
# ____________________________________________________________________________________________
# v = 2.1
# ...

# %%
for v in res:
    plt.plot(res[v]['b'],res[v]['p1'])
    plt.xlabel(' b')
    plt.ylabel('sigma')    
    plt.title('sigma (b)')

# %%
for v in res:
    plt.plot(res[v]['b'],res[v]['p2'])
    plt.xlabel(' b')
    plt.ylabel('log')    
    plt.title('log (b)')

# %%
for v in res:
    plt.plot(res[v]['b'],res[v]['p3'])
    plt.xlabel('b')
    plt.ylabel('exp(mu)')    
    plt.title('exp(mu) (b)')

# %% [markdown]
# # Распределение параметров логорифма

# %%
for v in res:
    print("____________________________________________________________________________________________")    
    print("v = {0}".format(v))
    plt.figure(1, figsize=(14,10))
    
    plt.subplot(221)
    plt.plot(res[v]['b'],res[v]['exp_x1'], 'g-')
    plt.xlabel('b')
    plt.ylabel('коэффициент при 2 степени')    
    plt.title('распределение коэффициента 2 степени от b')

    plt.subplot(222)
    plt.plot(res[v]['b'],res[v]['exp_x2'], 'r-')
    plt.xlabel(' b')
    plt.ylabel('коэффициент при 1 степени')    
    plt.title('распределение коэффициента 1 степени от b')

    plt.subplot(223)
    plt.plot(res[v]['b'],res[v]['exp_x3'], 'b-')
    plt.xlabel('b')
    plt.ylabel('свободный член')    
    plt.title('распределение свободного члена от b')

    plt.show()
# Out:
# ____________________________________________________________________________________________
# v = 0.5
# ____________________________________________________________________________________________
# v = 0.7
# ____________________________________________________________________________________________
# v = 0.9
# ____________________________________________________________________________________________
# v = 1.1
# ____________________________________________________________________________________________
# v = 1.3
# ____________________________________________________________________________________________
# v = 1.5
# ____________________________________________________________________________________________
# v = 1.7
# ____________________________________________________________________________________________
# v = 1.9
# ____________________________________________________________________________________________
# v = 2.1
# ...
